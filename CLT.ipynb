# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from numpy.random import normal
import matplotlib.mlab as mlab
from scipy.stats import gaussian_kde
from sklearn.neighbors.kde import KernelDensity



def experiment(trials):
    return np.mean(np.random.binomial(1, 0.5, trials) == 0)

ax = plt.gca()
ax.set_color_cycle(['b', 'r', 'g', 'c', 'k', 'y', 'm'])

for t in [100]:
    nums = np.array([experiment(t) for x in range(50000)])
    x = np.linspace(min(nums), max(nums), 50000)

    #kde = KernelDensity(kernel='gaussian', bandwidth=0.2)
    #kde.fit(nums[:, np.newaxis])
    #plt.plot(x, np.exp(kde.score_samples(x[:, np.newaxis])))
    
#     kde = gaussian_kde(nums) #, bw_method=0.1 / np.std(nums, ddof=1))
#     est = kde.evaluate(x)
#     plt.plot(x, est)

    plt.hist(nums, bins=20, normed=True)
    
    plt.plot(x, mlab.normpdf(x, np.mean(nums), np.std(nums, ddof=1)))
    plt.show()
