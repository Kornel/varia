# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import Ridge
from matplotlib import pyplot
from sklearn.metrics import mean_squared_error
import itertools

fig = plt.gcf()
fig.set_size_inches(12, 12)

xs = []
ys = []

p = 3./2
for x in np.linspace(-1.0, 1.0, 100):
    x2 = pow(1 - pow(x, p), 1./p)
    xs.append(x)
    ys.append(x2)

for x in np.linspace(1.0, -1.0, 100):
    x1 = -pow(1 - pow(x, p), 1./p)
    xs.append(x)
    ys.append(x1)

for x in np.linspace(1.0, -1.0, 100):
    x1 = -pow(1 - pow(x, p), 1./p)
    xs.append(-x)
    ys.append(x1)

for x in np.linspace(-1.0, 1.0, 100):
    x1 = pow(1 - pow(x, p), 1./p)
    xs.append(-x)
    ys.append(x1)

    
#plt.plot(x, y)
#plt.scatter(xs, ys)
plt.plot(xs, ys)

plt.show()
# Out:
# /Users/kornel.kielczewski/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:17: RuntimeWarning: invalid value encountered in double_scalars
# /Users/kornel.kielczewski/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:22: RuntimeWarning: invalid value encountered in double_scalars
# /Users/kornel.kielczewski/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:27: RuntimeWarning: invalid value encountered in double_scalars
# /Users/kornel.kielczewski/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:32: RuntimeWarning: invalid value encountered in double_scalars

# %%
# Out:
# array([ 1.        ,  0.95918367,  0.91836735,  0.87755102,  0.83673469,
#         0.79591837,  0.75510204,  0.71428571,  0.67346939,  0.63265306,
#         0.59183673,  0.55102041,  0.51020408,  0.46938776,  0.42857143,
#         0.3877551 ,  0.34693878,  0.30612245,  0.26530612,  0.2244898 ,
#         0.18367347,  0.14285714,  0.10204082,  0.06122449,  0.02040816,
#        -0.02040816, -0.06122449, -0.10204082, -0.14285714, -0.18367347,
#        -0.2244898 , -0.26530612, -0.30612245, -0.34693878, -0.3877551 ,
#        -0.42857143, -0.46938776, -0.51020408, -0.55102041, -0.59183673,
#        -0.63265306, -0.67346939, -0.71428571, -0.75510204, -0.79591837,
#        -0.83673469, -0.87755102, -0.91836735, -0.95918367, -1.        ])
